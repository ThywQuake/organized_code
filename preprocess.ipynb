# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datasets = {
    "era5": xr.open_dataset(
        "data/ERA5_tmp_0.25deg_monthly_198001-202312.nc", decode_times=False
    ),
    "exlwe": xr.open_dataset("data/extended_LWE_1980-2023.nc"),
    "fcti": xr.open_dataset("data/Fcti_resampled_to_0.25deg.nc"),
    "giems": xr.open_dataset("data/GIEMS-MC.nc"),
    "gleam": xr.open_dataset("data/GLEAM4_sm_0.25deg_monthly_198001-202312.nc"),
}

# %% [markdown]
# # Assign correct timestamp

# %% [markdown]
# # Fix units and variable names

# %% [markdown]
# # Fix other issues
