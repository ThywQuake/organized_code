# %%
import numpy as np

# %%
eval = np.load("output/eval/E/138_442.npy", allow_pickle=True)
eval
# Out:
# array({'Y_inv': {'y_pred_train': array([[0.12501903],
#        [0.12494098],
#        [0.12467539],
#        [0.12575835],
#        [0.12497003],
#        [0.1252204 ],
#        [0.12538682],
#        [0.12554233],
#        [0.12567835],
#        [0.12483677],
#        [0.12571108],
#        [0.12476398],
#        [0.12498126],
#        [0.12604262],
#        [0.12524879],
#        [0.12592313],
#        [0.12476162],
#        [0.12521131],
#        [0.12558755],
#        [0.12551498],
#        [0.1253066 ],
#        [0.125455  ],
#        [0.12588443],
#        [0.12527181],
#        [0.12572034],
#        [0.12501693],
#        [0.12580982],
#        [0.1249707 ],
#        [0.12569909],
#        [0.12457692],
#        [0.12555955],
#        [0.12556034],
#        [0.1257639 ],
#        [0.12606676],
#        [0.12530506],
#        [0.12556832],
#        [0.12579326],
#        [0.12529917],
#        [0.1254855 ],
#        [0.12478464],
#        [0.12558967],
#        [0.12494618],
# ...
